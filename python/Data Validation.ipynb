# %%
import numpy as np

# %%
label_data = np.load('labels.npz')

# %%
print len(label_data['labels'])
# Out:
# 3000

# %%
print np.sum(np.sum(label_data['labels'], axis=1) == 0)
# Out:
# 18

# %%
print len(label_data['names'])
# Out:
# 3000

# %%
for ix, item in enumerate(label_data['names']):
    print ix, item
# Out:
# 0 ISIC_0000000
# 1 ISIC_0000001
# 2 ISIC_0000002
# 3 ISIC_0000003
# 4 ISIC_0000004
# 5 ISIC_0000005
# 6 ISIC_0000006
# 7 ISIC_0000007
# 8 ISIC_0000008
# 9 ISIC_0000009
# 10 ISIC_0000010
# 11 ISIC_0000011
# 12 ISIC_0000012
# 13 ISIC_0000013
# 14 ISIC_0000014
# 15 ISIC_0000015
# 16 ISIC_0000016
# 17 ISIC_0000017
# 18 ISIC_0000018
# 19 ISIC_0000019
# 20 ISIC_0000020
# 21 ISIC_0000021
# 22 ISIC_0000022
# 23 ISIC_0000023
# 24 ISIC_0000024
# 25 ISIC_0000025
# 26 ISIC_0000026
# 27 ISIC_0000027
# 28 ISIC_0000028
# 29 ISIC_0000029
# 30 ISIC_0000030
# 31 ISIC_0000031
# 32 ISIC_0000032
# 33 ISIC_0000033
# 34 ISIC_0000034
# 35 ISIC_0000035
# 36 ISIC_0000036
# 37 ISIC_0000037
# 38 ISIC_0000038
# 39 ISIC_0000039
# 40 ISIC_0000040
# 41 ISIC_0000041
# 42 ISIC_0000042
# 43 ISIC_0000043
# 44 ISIC_0000044
# 45 ISIC_0000045
# 46 ISIC_0000046
# 47 ISIC_0000047
# 48 ISIC_0000048
# 49 ISIC_0000049
# 50 ISIC_0000050
# 51 ISIC_0000051
# 52 ISIC_0000052
# 53 ISIC_0000053
# 54 ISIC_0000054
# 55 ISIC_0000055
# ...
