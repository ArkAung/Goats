# %%
from PIL import Image
import glob
import numpy as np
import matplotlib.pyplot as plt

# %%
input_image = Image.open("ISIC_UDA-2_1/ISIC_0001100.jpg")

# %%
input_image = input_image.resize((100,100),Image.ANTIALIAS)

# %%
input_image
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x1089D9590>

# %%
numpy_arr = np.asarray(input_image)

# %%
numpy_arr.shape
# Out:
# (100, 100, 3)

# %%
w, h = input_image.size
cropped_image = input_image.crop((10, 10, w-10, h-10))

# %%
numpy_arr = np.asarray(cropped_image)

# %%
numpy_arr.shape
# Out:
# (80, 80, 3)

# %%
plt.show(plt.imshow(numpy_arr))

# %%
def image_process(filename):
    im=Image.open(filename)
    im = im.resize((100,100),Image.ANTIALIAS)
    w, h = im.size
    cropped_image = im.crop((10, 10, w-10, h-10))
    numpy_arr = np.asarray(cropped_image)
    return numpy_arr

# %%
filelist = glob.glob("ISIC_UDA-2_1/*.jpg")

# %%
x = np.array([image_process(fname) for fname in filelist])

# %%
np.save('ISIC_UDA-2_1.npy', x)

# %%
data_load = np.load('ISIC_UDA-2_1.npy')

# %%
data_load.shape
# Out:
# (60, 80, 80, 3)
