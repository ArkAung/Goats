# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
input_input = np.load('/work/aaung/ISIC-images/ISIC_MSK-4_1/image.npy')

# %%
input_input.shape
# Out:
# (947, 80, 80, 3)

# %%
for i in range(20):
    plt.show(plt.imshow(input_input[i,:,:,:]))

# %%
root = '/work/aaung/ISIC-images'

# %%
dir_list = ['ISIC_UDA','ISIC_UDA-2_1','ISIC_MSK-1_1','ISIC_MSK-3_1','ISIC_MSK-4_1']

# %%
for i in dir_list:
    print root + '/'+ i + '/images.npy'
# Out:
# /work/aaung/ISIC-images/ISIC_UDA-1_1/images.npy
# /work/aaung/ISIC-images/ISIC_UDA-2_1/images.npy
# /work/aaung/ISIC-images/ISIC_MSK-1_1/images.npy
# /work/aaung/ISIC-images/ISIC_MSK-3_1/images.npy
# /work/aaung/ISIC-images/ISIC_MSK-4_1/images.npy

# %%
from PIL import Image

input_image = Image.open('/work/aaung/ISIC-images/tmp/ISIC_0000012.jpg')

# %%
input_image.size
# Out:
# (1022, 767)
